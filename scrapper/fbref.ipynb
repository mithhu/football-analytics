# %%
# !pip install undetected-chromedriver
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 KB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 4.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.3/173.3 KB 5.9 MB/s eta 0:00:00
# ...
#   Using cached websocket_client-1.9.0-py3-none-any.whl (82 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.7/512.7 KB 1.8 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using legacy 'setup.py install' for undetected-chromedriver, since package 'wheel' is not installed.
# ...
#   Running setup.py install for undetected-chromedriver ... done
# ...
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/mahamudulhasanmithhu/.pyenv/versions/3.9.13/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import undetected_chromedriver as uc

from bs4 import BeautifulSoup

# %%
driver = uc.Chrome(version_main=144)

# %%
pip install -U undetected-chromedriver
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/mahamudulhasanmithhu/.pyenv/versions/3.9.13/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
driver.get("https://fbref.com/en/comps/8/2023-2024/2023-2024-Champions-League-Stats")

# %%
from io import StringIO

# %%
df = pd.read_html(driver.page_source, attrs={"id": "stats_squads_standard_for"})[0]
# Out:
# /var/folders/rm/8sf3dfrx23n5yr19qhb9648w0000gn/T/ipykernel_74013/1815874445.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(driver.page_source, attrs={"id": "stats_squads_standard_for"})[0]

# %%
df.head()
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0          be Antwerp                 20               24.5
# 1         eng Arsenal                 23               25.2
# 2  es Atlético Madrid                 22               29.4
# 3        es Barcelona                 25               26.5
# 4    de Bayern Munich                 23               27.6
#
#   Unnamed: 3_level_0 Playing Time                    Performance      ...  \
#                 Poss           MP Starts   Min   90s         Gls Ast  ...
# 0               43.2            6     66   540   6.0           6   4  ...
# 1               56.5           10    110   930  10.3          19  16  ...
# 2               49.1           10    110   930  10.3          20  11  ...
# 3               54.2           10    110   900  10.0          19  18  ...
# 4               54.4           12    132  1080  12.0          21  16  ...
#
# ...

# %%
df.columns = ['_'.join(col).strip() for col in df.columns.values]

# %%
df.head()
# Out:
#   Unnamed: 0_level_0_Squad  Unnamed: 1_level_0_# Pl  Unnamed: 2_level_0_Age  \
# 0               be Antwerp                       20                    24.5
# 1              eng Arsenal                       23                    25.2
# 2       es Atlético Madrid                       22                    29.4
# 3             es Barcelona                       25                    26.5
# 4         de Bayern Munich                       23                    27.6
#
#    Unnamed: 3_level_0_Poss  Playing Time_MP  Playing Time_Starts  \
# 0                     43.2                6                   66
# 1                     56.5               10                  110
# 2                     49.1               10                  110
# 3                     54.2               10                  110
# 4                     54.4               12                  132
#
#    Playing Time_Min  Playing Time_90s  Performance_Gls  Performance_Ast  ...  \
# ...

# %%
player_stats = pd.read_html(driver.page_source, attrs={"id": "stats_standard"})[0]
player_stats.columns = ['_'.join(col).strip() for col in player_stats.columns.values]

player_stats.head()
# Out:
# /var/folders/rm/8sf3dfrx23n5yr19qhb9648w0000gn/T/ipykernel_74013/787434050.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   player_stats = pd.read_html(driver.page_source, attrs={"id": "stats_standard"})[0]
#   Unnamed: 0_level_0_Rk Unnamed: 1_level_0_Player Unnamed: 2_level_0_Nation  \
# 0                     1       Patrick van Aanholt                    nl NED
# 1                     2          Brenden Aaronson                    us USA
# 2                     3         Salis Abdul Samed                    gh GHA
# 3                     4          Francesco Acerbi                    it ITA
# 4                     5             Elias Achouri                    tn TUN
#
#   Unnamed: 3_level_0_Pos Unnamed: 4_level_0_Squad Unnamed: 5_level_0_Age  \
# 0                  DF,MF                   nl PSV                     32
# ...
